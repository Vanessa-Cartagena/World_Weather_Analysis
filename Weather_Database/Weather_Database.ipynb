# %%
# Module 6 Challenge

# %%
import pandas as pd
import matplotlib.pyplot as plt
import json
import numpy as np
import requests
from citipy import citipy
from config import weather_api_key
from datetime import datetime 
import time

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=39704a67a8b5743d76123184d4d303ac

# %%
coordinates = list(lat_lngs)

# %%
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 762

# %%
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        description = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Description": description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | preeceville
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | leningradskiy
# Processing Record 4 of Set 1 | denpasar
# Processing Record 5 of Set 1 | arraial do cabo
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | yulara
# Processing Record 8 of Set 1 | lebu
# Processing Record 9 of Set 1 | sorong
# Processing Record 10 of Set 1 | tiksi
# Processing Record 11 of Set 1 | puerto ayora
# Processing Record 12 of Set 1 | sarangani
# Processing Record 13 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 1 | rocha
# Processing Record 15 of Set 1 | mar del plata
# Processing Record 16 of Set 1 | hithadhoo
# Processing Record 17 of Set 1 | nouadhibou
# Processing Record 18 of Set 1 | butaritari
# Processing Record 19 of Set 1 | hobart
# Processing Record 20 of Set 1 | chokurdakh
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | bubaque
# Processing Record 23 of Set 1 | alofi
# Processing Record 24 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 1 | saint-philippe
# Processing Record 27 of Set 1 | east london
# Processing Record 28 of Set 1 | mahanoro
# Processing Record 29 of Set 1 | namatanai
# Processing Record 30 of Set 1 | geraldton
# Processing Record 31 of Set 1 | hermanus
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | yurginskoye
# Processing Record 34 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 1 | vaini
# Processing Record 36 of Set 1 | lakatoro
# Processing Record 37 of Set 1 | mataura
# Processing Record 38 of Set 1 | jamestown
# Processing Record 39 of Set 1 | carnarvon
# Processing Record 40 of Set 1 | bredasdorp
# Processing Record 41 of Set 1 | fortuna
# Processing Record 42 of Set 1 | yamada
# Processing Record 43 of Set 1 | punta arenas
# Processing Record 44 of Set 1 | chapais
# Processing Record 45 of Set 1 | kaitangata
# Processing Record 46 of Set 1 | half moon bay
# Processing Record 47 of Set 1 | luderitz
# Processing Record 48 of Set 1 | synya
# Processing Record 49 of Set 1 | puerto madero
# Processing Record 50 of Set 1 | barrow
# Processing Record 1 of Set 2 | port elizabeth
# Processing Record 2 of Set 2 | chitrakonda
# Processing Record 3 of Set 2 | lannion
# Processing Record 4 of Set 2 | kharan
# Processing Record 5 of Set 2 | mason city
# Processing Record 6 of Set 2 | labuhan
# Processing Record 7 of Set 2 | eucaliptus
# Processing Record 8 of Set 2 | victoria
# Processing Record 9 of Set 2 | torbay
# Processing Record 10 of Set 2 | sai buri
# Processing Record 11 of Set 2 | ancud
# Processing Record 12 of Set 2 | atuona
# Processing Record 13 of Set 2 | ponta delgada
# Processing Record 14 of Set 2 | villarrica
# Processing Record 15 of Set 2 | cayenne
# Processing Record 16 of Set 2 | inirida
# Processing Record 17 of Set 2 | castro
# Processing Record 18 of Set 2 | amga
# Processing Record 19 of Set 2 | port lincoln
# Processing Record 20 of Set 2 | hilo
# Processing Record 21 of Set 2 | jabinyanah
# Processing Record 22 of Set 2 | turukhansk
# Processing Record 23 of Set 2 | faanui
# Processing Record 24 of Set 2 | kapaa
# Processing Record 25 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 2 | nikolskoye
# Processing Record 28 of Set 2 | rayachoti
# Processing Record 29 of Set 2 | aklavik
# Processing Record 30 of Set 2 | airai
# Processing Record 31 of Set 2 | sola
# Processing Record 32 of Set 2 | meulaboh
# Processing Record 33 of Set 2 | shingu
# Processing Record 34 of Set 2 | brownsville
# Processing Record 35 of Set 2 | bud
# Processing Record 36 of Set 2 | hanna
# Processing Record 37 of Set 2 | bangkalan
# Processing Record 38 of Set 2 | tuktoyaktuk
# Processing Record 39 of Set 2 | tiznit
# Processing Record 40 of Set 2 | arrecife
# Processing Record 41 of Set 2 | bluff
# Processing Record 42 of Set 2 | bocaranga
# City not found. Skipping...
# Processing Record 43 of Set 2 | saskylakh
# Processing Record 44 of Set 2 | taltal
# Processing Record 45 of Set 2 | buctzotz
# Processing Record 46 of Set 2 | corbelia
# Processing Record 47 of Set 2 | itarema
# Processing Record 48 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 2 | vardo
# Processing Record 50 of Set 2 | bilibino
# Processing Record 1 of Set 3 | avarua
# Processing Record 2 of Set 3 | lompoc
# Processing Record 3 of Set 3 | skalistyy
# City not found. Skipping...
# Processing Record 4 of Set 3 | mao
# Processing Record 5 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 3 | port alfred
# Processing Record 7 of Set 3 | flinders
# Processing Record 8 of Set 3 | new norfolk
# Processing Record 9 of Set 3 | ostrovnoy
# Processing Record 10 of Set 3 | qaanaaq
# Processing Record 11 of Set 3 | kovylkino
# Processing Record 12 of Set 3 | teahupoo
# Processing Record 13 of Set 3 | waipawa
# Processing Record 14 of Set 3 | tasiilaq
# Processing Record 15 of Set 3 | shimoda
# Processing Record 16 of Set 3 | kant
# Processing Record 17 of Set 3 | nelson bay
# Processing Record 18 of Set 3 | port hedland
# Processing Record 19 of Set 3 | aykhal
# Processing Record 20 of Set 3 | klaksvik
# Processing Record 21 of Set 3 | pryozerne
# Processing Record 22 of Set 3 | zhigansk
# Processing Record 23 of Set 3 | cherskiy
# Processing Record 24 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 3 | ribeira grande
# Processing Record 26 of Set 3 | riviere-du-loup
# Processing Record 27 of Set 3 | neiafu
# Processing Record 28 of Set 3 | challapalle
# Processing Record 29 of Set 3 | champerico
# Processing Record 30 of Set 3 | ngawen
# Processing Record 31 of Set 3 | muros
# Processing Record 32 of Set 3 | coquimbo
# Processing Record 33 of Set 3 | irtyshskiy
# Processing Record 34 of Set 3 | yellowknife
# Processing Record 35 of Set 3 | alcantara
# Processing Record 36 of Set 3 | lagos
# Processing Record 37 of Set 3 | richards bay
# Processing Record 38 of Set 3 | riverton
# Processing Record 39 of Set 3 | akdepe
# Processing Record 40 of Set 3 | pevek
# Processing Record 41 of Set 3 | touros
# Processing Record 42 of Set 3 | makakilo city
# Processing Record 43 of Set 3 | mackenzie
# Processing Record 44 of Set 3 | lasa
# Processing Record 45 of Set 3 | te anau
# Processing Record 46 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 3 | ambilobe
# Processing Record 48 of Set 3 | souillac
# Processing Record 49 of Set 3 | gabu
# Processing Record 50 of Set 3 | jutai
# Processing Record 1 of Set 4 | ventspils
# Processing Record 2 of Set 4 | nadvoitsy
# Processing Record 3 of Set 4 | bengkulu
# Processing Record 4 of Set 4 | sao joao da barra
# Processing Record 5 of Set 4 | maceio
# Processing Record 6 of Set 4 | diego de almagro
# Processing Record 7 of Set 4 | pemangkat
# Processing Record 8 of Set 4 | kikwit
# Processing Record 9 of Set 4 | kibungo
# Processing Record 10 of Set 4 | upernavik
# Processing Record 11 of Set 4 | dalbandin
# Processing Record 12 of Set 4 | cabo san lucas
# Processing Record 13 of Set 4 | kerrobert
# Processing Record 14 of Set 4 | wanning
# Processing Record 15 of Set 4 | komsomolskiy
# Processing Record 16 of Set 4 | ankang
# Processing Record 17 of Set 4 | georgetown
# Processing Record 18 of Set 4 | inyonga
# Processing Record 19 of Set 4 | esmeraldas
# Processing Record 20 of Set 4 | horsham
# Processing Record 21 of Set 4 | cidreira
# Processing Record 22 of Set 4 | kidal
# Processing Record 23 of Set 4 | whitehorse
# Processing Record 24 of Set 4 | san ignacio
# Processing Record 25 of Set 4 | barberton
# Processing Record 26 of Set 4 | chuy
# Processing Record 27 of Set 4 | marathon
# Processing Record 28 of Set 4 | acapulco
# Processing Record 29 of Set 4 | takaka
# Processing Record 30 of Set 4 | borova
# Processing Record 31 of Set 4 | porto velho
# Processing Record 32 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 4 | corrales
# Processing Record 34 of Set 4 | buenos aires
# Processing Record 35 of Set 4 | saint-pierre
# Processing Record 36 of Set 4 | beirut
# Processing Record 37 of Set 4 | doka
# Processing Record 38 of Set 4 | alakurtti
# Processing Record 39 of Set 4 | kodiak
# Processing Record 40 of Set 4 | saint george
# Processing Record 41 of Set 4 | veselynove
# Processing Record 42 of Set 4 | kibala
# Processing Record 43 of Set 4 | orlik
# Processing Record 44 of Set 4 | kargil
# Processing Record 45 of Set 4 | aguimes
# Processing Record 46 of Set 4 | khatanga
# Processing Record 47 of Set 4 | dingle
# Processing Record 48 of Set 4 | nome
# Processing Record 49 of Set 4 | seydi
# Processing Record 50 of Set 4 | caravelas
# Processing Record 1 of Set 5 | kimbe
# Processing Record 2 of Set 5 | coahuayana
# Processing Record 3 of Set 5 | batemans bay
# Processing Record 4 of Set 5 | lavrentiya
# Processing Record 5 of Set 5 | san carlos de bariloche
# Processing Record 6 of Set 5 | lagoa
# Processing Record 7 of Set 5 | jiddah
# City not found. Skipping...
# Processing Record 8 of Set 5 | luzhou
# Processing Record 9 of Set 5 | meybod
# Processing Record 10 of Set 5 | mount gambier
# Processing Record 11 of Set 5 | gazli
# Processing Record 12 of Set 5 | anadyr
# Processing Record 13 of Set 5 | nuevo casas grandes
# Processing Record 14 of Set 5 | leshukonskoye
# Processing Record 15 of Set 5 | calbuco
# Processing Record 16 of Set 5 | jinchengjiang
# City not found. Skipping...
# Processing Record 17 of Set 5 | skjervoy
# Processing Record 18 of Set 5 | samarinda
# Processing Record 19 of Set 5 | tuggurt
# City not found. Skipping...
# Processing Record 20 of Set 5 | grand gaube
# Processing Record 21 of Set 5 | umm kaddadah
# Processing Record 22 of Set 5 | kysyl-syr
# Processing Record 23 of Set 5 | batagay-alyta
# Processing Record 24 of Set 5 | lolodorf
# Processing Record 25 of Set 5 | la paz
# Processing Record 26 of Set 5 | borovoy
# Processing Record 27 of Set 5 | hami
# Processing Record 28 of Set 5 | codrington
# Processing Record 29 of Set 5 | tacuati
# Processing Record 30 of Set 5 | oussouye
# Processing Record 31 of Set 5 | naze
# Processing Record 32 of Set 5 | sorland
# Processing Record 33 of Set 5 | bolobo
# Processing Record 34 of Set 5 | beloha
# Processing Record 35 of Set 5 | bathsheba
# Processing Record 36 of Set 5 | san quintin
# Processing Record 37 of Set 5 | fiditi
# Processing Record 38 of Set 5 | trincomalee
# Processing Record 39 of Set 5 | port hardy
# Processing Record 40 of Set 5 | iqaluit
# Processing Record 41 of Set 5 | fare
# Processing Record 42 of Set 5 | lienz
# Processing Record 43 of Set 5 | san juan
# Processing Record 44 of Set 5 | belmonte
# Processing Record 45 of Set 5 | margate
# Processing Record 46 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 47 of Set 5 | newport
# Processing Record 48 of Set 5 | hirna
# Processing Record 49 of Set 5 | clyde river
# Processing Record 50 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 6 | columbus
# Processing Record 2 of Set 6 | butembo
# Processing Record 3 of Set 6 | kindia
# Processing Record 4 of Set 6 | vypolzovo
# Processing Record 5 of Set 6 | erdenet
# Processing Record 6 of Set 6 | ukiah
# Processing Record 7 of Set 6 | cape town
# Processing Record 8 of Set 6 | waingapu
# Processing Record 9 of Set 6 | namibe
# Processing Record 10 of Set 6 | skowhegan
# Processing Record 11 of Set 6 | ahipara
# Processing Record 12 of Set 6 | portland
# Processing Record 13 of Set 6 | quesnel
# Processing Record 14 of Set 6 | laguna
# Processing Record 15 of Set 6 | chingirlau
# Processing Record 16 of Set 6 | pyay
# Processing Record 17 of Set 6 | camacha
# Processing Record 18 of Set 6 | hamina
# Processing Record 19 of Set 6 | arman
# Processing Record 20 of Set 6 | dorado
# Processing Record 21 of Set 6 | miguel calmon
# Processing Record 22 of Set 6 | axim
# Processing Record 23 of Set 6 | liwale
# Processing Record 24 of Set 6 | mahebourg
# Processing Record 25 of Set 6 | north platte
# Processing Record 26 of Set 6 | sao filipe
# Processing Record 27 of Set 6 | rodrigues alves
# Processing Record 28 of Set 6 | auki
# Processing Record 29 of Set 6 | tilichiki
# Processing Record 30 of Set 6 | paita
# Processing Record 31 of Set 6 | guapore
# Processing Record 32 of Set 6 | mitsamiouli
# Processing Record 33 of Set 6 | abu dhabi
# Processing Record 34 of Set 6 | dikson
# Processing Record 35 of Set 6 | mocuba
# Processing Record 36 of Set 6 | ponta do sol
# Processing Record 37 of Set 6 | olinda
# Processing Record 38 of Set 6 | ruidoso
# Processing Record 39 of Set 6 | sataua
# City not found. Skipping...
# Processing Record 40 of Set 6 | riyadh
# Processing Record 41 of Set 6 | clearlake
# Processing Record 42 of Set 6 | katsuura
# Processing Record 43 of Set 6 | zhaoqing
# Processing Record 44 of Set 6 | manzanillo
# Processing Record 45 of Set 6 | berlevag
# Processing Record 46 of Set 6 | cedar city
# Processing Record 47 of Set 6 | deer lake
# Processing Record 48 of Set 6 | vila velha
# Processing Record 49 of Set 6 | khandyga
# Processing Record 50 of Set 6 | imbituba
# Processing Record 1 of Set 7 | kudahuvadhoo
# Processing Record 2 of Set 7 | hede
# Processing Record 3 of Set 7 | poronaysk
# Processing Record 4 of Set 7 | yarensk
# Processing Record 5 of Set 7 | huangzhai
# Processing Record 6 of Set 7 | nouakchott
# Processing Record 7 of Set 7 | saint andrews
# Processing Record 8 of Set 7 | salina
# Processing Record 9 of Set 7 | lazaro cardenas
# Processing Record 10 of Set 7 | faya
# Processing Record 11 of Set 7 | ust-tsilma
# Processing Record 12 of Set 7 | raga
# Processing Record 13 of Set 7 | pingzhuang
# Processing Record 14 of Set 7 | aksu
# Processing Record 15 of Set 7 | lorengau
# Processing Record 16 of Set 7 | marsh harbour
# Processing Record 17 of Set 7 | bandarbeyla
# Processing Record 18 of Set 7 | yining
# Processing Record 19 of Set 7 | noshiro
# Processing Record 20 of Set 7 | monster
# Processing Record 21 of Set 7 | bambous virieux
# Processing Record 22 of Set 7 | esperance
# Processing Record 23 of Set 7 | reichenau
# Processing Record 24 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 7 | paamiut
# Processing Record 26 of Set 7 | honiara
# Processing Record 27 of Set 7 | chimbarongo
# Processing Record 28 of Set 7 | luwuk
# Processing Record 29 of Set 7 | tukrah
# Processing Record 30 of Set 7 | norman wells
# Processing Record 31 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 7 | mehamn
# Processing Record 33 of Set 7 | mariental
# Processing Record 34 of Set 7 | isangel
# Processing Record 35 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 36 of Set 7 | college
# Processing Record 37 of Set 7 | deputatskiy
# Processing Record 38 of Set 7 | mount pleasant
# Processing Record 39 of Set 7 | korla
# Processing Record 40 of Set 7 | acajutla
# Processing Record 41 of Set 7 | palmas
# Processing Record 42 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 7 | chabahar
# Processing Record 44 of Set 7 | lichinga
# Processing Record 45 of Set 7 | borogontsy
# Processing Record 46 of Set 7 | broken hill
# Processing Record 47 of Set 7 | yialos
# City not found. Skipping...
# Processing Record 48 of Set 7 | pacific grove
# Processing Record 49 of Set 7 | lovozero
# Processing Record 50 of Set 7 | lima
# Processing Record 1 of Set 8 | rio gallegos
# Processing Record 2 of Set 8 | terrace bay
# Processing Record 3 of Set 8 | merauke
# Processing Record 4 of Set 8 | pisco
# Processing Record 5 of Set 8 | tarhunah
# City not found. Skipping...
# Processing Record 6 of Set 8 | beringovskiy
# Processing Record 7 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 8 | bethel
# Processing Record 9 of Set 8 | tanout
# Processing Record 10 of Set 8 | manono
# Processing Record 11 of Set 8 | kilemary
# Processing Record 12 of Set 8 | ilulissat
# Processing Record 13 of Set 8 | necochea
# Processing Record 14 of Set 8 | camapua
# Processing Record 15 of Set 8 | nuqui
# Processing Record 16 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 17 of Set 8 | kargopol
# Processing Record 18 of Set 8 | bongandanga
# Processing Record 19 of Set 8 | sosva
# Processing Record 20 of Set 8 | joensuu
# Processing Record 21 of Set 8 | buala
# Processing Record 22 of Set 8 | srednekolymsk
# Processing Record 23 of Set 8 | miquelon
# Processing Record 24 of Set 8 | port blair
# Processing Record 25 of Set 8 | vanavara
# Processing Record 26 of Set 8 | talnakh
# Processing Record 27 of Set 8 | takoradi
# Processing Record 28 of Set 8 | boppard
# Processing Record 29 of Set 8 | pierre
# Processing Record 30 of Set 8 | malinovka
# Processing Record 31 of Set 8 | verkhnyaya inta
# Processing Record 32 of Set 8 | kharp
# Processing Record 33 of Set 8 | santa rosa
# Processing Record 34 of Set 8 | sylvan lake
# Processing Record 35 of Set 8 | wattegama
# Processing Record 36 of Set 8 | paraiso
# Processing Record 37 of Set 8 | wamba
# Processing Record 38 of Set 8 | saiha
# Processing Record 39 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 40 of Set 8 | port augusta
# Processing Record 41 of Set 8 | dzilam gonzalez
# Processing Record 42 of Set 8 | ushtobe
# Processing Record 43 of Set 8 | krasnovishersk
# Processing Record 44 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 45 of Set 8 | goryachiy klyuch
# Processing Record 46 of Set 8 | sur
# Processing Record 47 of Set 8 | kahului
# Processing Record 48 of Set 8 | daru
# Processing Record 49 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 8 | la ronge
# Processing Record 1 of Set 9 | colac
# Processing Record 2 of Set 9 | awjilah
# Processing Record 3 of Set 9 | ust-koksa
# Processing Record 4 of Set 9 | petropavl
# Processing Record 5 of Set 9 | severo-kurilsk
# Processing Record 6 of Set 9 | thompson
# Processing Record 7 of Set 9 | opuwo
# Processing Record 8 of Set 9 | san patricio
# Processing Record 9 of Set 9 | hinton
# Processing Record 10 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 11 of Set 9 | conde
# Processing Record 12 of Set 9 | asau
# Processing Record 13 of Set 9 | saint-joseph
# Processing Record 14 of Set 9 | annau
# Processing Record 15 of Set 9 | qianan
# Processing Record 16 of Set 9 | lamar
# Processing Record 17 of Set 9 | ballarat
# Processing Record 18 of Set 9 | san cristobal
# Processing Record 19 of Set 9 | ahmadpur sial
# Processing Record 20 of Set 9 | provideniya
# Processing Record 21 of Set 9 | madison
# Processing Record 22 of Set 9 | muzquiz
# City not found. Skipping...
# Processing Record 23 of Set 9 | marion
# Processing Record 24 of Set 9 | panguna
# Processing Record 25 of Set 9 | rock springs
# Processing Record 26 of Set 9 | khash
# Processing Record 27 of Set 9 | hit
# Processing Record 28 of Set 9 | hopkinton
# Processing Record 29 of Set 9 | grand-santi
# Processing Record 30 of Set 9 | vila franca do campo
# Processing Record 31 of Set 9 | molepolole
# Processing Record 32 of Set 9 | wuning
# Processing Record 33 of Set 9 | inuvik
# Processing Record 34 of Set 9 | hualmay
# Processing Record 35 of Set 9 | tateyama
# Processing Record 36 of Set 9 | kloulklubed
# Processing Record 37 of Set 9 | obudovac
# Processing Record 38 of Set 9 | los llanos de aridane
# Processing Record 39 of Set 9 | flin flon
# Processing Record 40 of Set 9 | terrace
# Processing Record 41 of Set 9 | japura
# Processing Record 42 of Set 9 | makungu
# Processing Record 43 of Set 9 | borlange
# City not found. Skipping...
# Processing Record 44 of Set 9 | babanusah
# City not found. Skipping...
# Processing Record 45 of Set 9 | avera
# Processing Record 46 of Set 9 | kaeo
# Processing Record 47 of Set 9 | vao
# Processing Record 48 of Set 9 | westport
# Processing Record 49 of Set 9 | manchester
# Processing Record 50 of Set 9 | aviemore
# Processing Record 1 of Set 10 | waddan
# Processing Record 2 of Set 10 | kutum
# Processing Record 3 of Set 10 | mago
# Processing Record 4 of Set 10 | ahuimanu
# Processing Record 5 of Set 10 | jalu
# Processing Record 6 of Set 10 | tawau
# Processing Record 7 of Set 10 | popondetta
# Processing Record 8 of Set 10 | erzincan
# Processing Record 9 of Set 10 | imeni poliny osipenko
# Processing Record 10 of Set 10 | ulaangom
# Processing Record 11 of Set 10 | karauzyak
# City not found. Skipping...
# Processing Record 12 of Set 10 | saint anthony
# Processing Record 13 of Set 10 | krylovskaya
# Processing Record 14 of Set 10 | amahai
# Processing Record 15 of Set 10 | tianpeng
# Processing Record 16 of Set 10 | santiago
# Processing Record 17 of Set 10 | katobu
# Processing Record 18 of Set 10 | novi bilokorovychi
# Processing Record 19 of Set 10 | zwedru
# Processing Record 20 of Set 10 | mogadishu
# Processing Record 21 of Set 10 | kashi
# Processing Record 22 of Set 10 | dakar
# Processing Record 23 of Set 10 | akim swedru
# Processing Record 24 of Set 10 | haines junction
# Processing Record 25 of Set 10 | talaya
# Processing Record 26 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 27 of Set 10 | presidente dutra
# Processing Record 28 of Set 10 | liverpool
# Processing Record 29 of Set 10 | bundaberg
# Processing Record 30 of Set 10 | dunedin
# Processing Record 31 of Set 10 | santa cruz de la palma
# Processing Record 32 of Set 10 | tautira
# Processing Record 33 of Set 10 | azanka
# Processing Record 34 of Set 10 | bulancak
# Processing Record 35 of Set 10 | biak
# Processing Record 36 of Set 10 | danville
# Processing Record 37 of Set 10 | amalapuram
# Processing Record 38 of Set 10 | hasaki
# Processing Record 39 of Set 10 | palmer
# Processing Record 40 of Set 10 | husavik
# Processing Record 41 of Set 10 | beian
# Processing Record 42 of Set 10 | sabha
# Processing Record 43 of Set 10 | the valley
# Processing Record 44 of Set 10 | viseu
# Processing Record 45 of Set 10 | kavaratti
# Processing Record 46 of Set 10 | soller
# Processing Record 47 of Set 10 | olafsvik
# Processing Record 48 of Set 10 | bor
# Processing Record 49 of Set 10 | acarau
# Processing Record 50 of Set 10 | saldanha
# Processing Record 1 of Set 11 | belaya gora
# Processing Record 2 of Set 11 | togur
# Processing Record 3 of Set 11 | joshimath
# Processing Record 4 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 5 of Set 11 | masallatah
# Processing Record 6 of Set 11 | eau claire
# Processing Record 7 of Set 11 | harunabad
# Processing Record 8 of Set 11 | amazar
# Processing Record 9 of Set 11 | moron
# Processing Record 10 of Set 11 | alugan
# Processing Record 11 of Set 11 | peleduy
# Processing Record 12 of Set 11 | yako
# Processing Record 13 of Set 11 | varna
# Processing Record 14 of Set 11 | progreso
# Processing Record 15 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 16 of Set 11 | katherine
# Processing Record 17 of Set 11 | grand-bourg
# Processing Record 18 of Set 11 | ouesso
# Processing Record 19 of Set 11 | rapar
# Processing Record 20 of Set 11 | ayan
# Processing Record 21 of Set 11 | santander
# Processing Record 22 of Set 11 | edd
# Processing Record 23 of Set 11 | huarmey
# Processing Record 24 of Set 11 | chumikan
# Processing Record 25 of Set 11 | kuusamo
# Processing Record 26 of Set 11 | yumen
# Processing Record 27 of Set 11 | owosso
# Processing Record 28 of Set 11 | kaa-khem
# Processing Record 29 of Set 11 | constitucion
# Processing Record 30 of Set 11 | parfenyevo
# Processing Record 31 of Set 11 | rorvik
# Processing Record 32 of Set 11 | tahoua
# Processing Record 33 of Set 11 | jibuti
# Processing Record 34 of Set 11 | beni suef
# Processing Record 35 of Set 11 | sangar
# Processing Record 36 of Set 11 | dabhol
# Processing Record 37 of Set 11 | cockburn town
# Processing Record 38 of Set 11 | port pirie
# Processing Record 39 of Set 11 | sudzha
# Processing Record 40 of Set 11 | mount isa
# Processing Record 41 of Set 11 | antofagasta
# Processing Record 42 of Set 11 | moree
# Processing Record 43 of Set 11 | miri
# Processing Record 44 of Set 11 | umea
# Processing Record 45 of Set 11 | ostersund
# Processing Record 46 of Set 11 | hofn
# Processing Record 47 of Set 11 | evanston
# Processing Record 48 of Set 11 | ludvika
# Processing Record 49 of Set 11 | skibbereen
# Processing Record 50 of Set 11 | salalah
# Processing Record 1 of Set 12 | homer
# Processing Record 2 of Set 12 | chernyshevskiy
# Processing Record 3 of Set 12 | hailar
# Processing Record 4 of Set 12 | bedele
# Processing Record 5 of Set 12 | lugovoy
# Processing Record 6 of Set 12 | datong
# Processing Record 7 of Set 12 | puerto leguizamo
# Processing Record 8 of Set 12 | ambovombe
# Processing Record 9 of Set 12 | charagua
# Processing Record 10 of Set 12 | bulawayo
# Processing Record 11 of Set 12 | semirom
# Processing Record 12 of Set 12 | nizhneudinsk
# Processing Record 13 of Set 12 | point fortin
# Processing Record 14 of Set 12 | naryan-mar
# Processing Record 15 of Set 12 | plettenberg bay
# Processing Record 16 of Set 12 | pilar
# Processing Record 17 of Set 12 | goderich
# Processing Record 18 of Set 12 | zasheyek
# Processing Record 19 of Set 12 | nanortalik
# Processing Record 20 of Set 12 | navalmoral de la mata
# Processing Record 21 of Set 12 | fecamp
# Processing Record 22 of Set 12 | bereda
# Processing Record 23 of Set 12 | forestville
# Processing Record 24 of Set 12 | chicama
# Processing Record 25 of Set 12 | weiser
# Processing Record 26 of Set 12 | ixtapa
# Processing Record 27 of Set 12 | danielskuil
# Processing Record 28 of Set 12 | bystryy istok
# Processing Record 29 of Set 12 | puerto escondido
# Processing Record 30 of Set 12 | rumonge
# Processing Record 31 of Set 12 | buraydah
# Processing Record 32 of Set 12 | turtkul
# City not found. Skipping...
# Processing Record 33 of Set 12 | crab hill
# City not found. Skipping...
# Processing Record 34 of Set 12 | eyl
# Processing Record 35 of Set 12 | oytal
# Processing Record 36 of Set 12 | oistins
# Processing Record 37 of Set 12 | sioux lookout
# Processing Record 38 of Set 12 | victor harbor
# Processing Record 39 of Set 12 | yendi
# Processing Record 40 of Set 12 | asyut
# Processing Record 41 of Set 12 | egvekinot
# Processing Record 42 of Set 12 | cowra
# Processing Record 43 of Set 12 | adrar
# Processing Record 44 of Set 12 | paragominas
# Processing Record 45 of Set 12 | saint-leu
# Processing Record 46 of Set 12 | harper
# Processing Record 47 of Set 12 | mayo
# Processing Record 48 of Set 12 | sukumo
# Processing Record 49 of Set 12 | amapa
# Processing Record 50 of Set 12 | poiana stampei
# Processing Record 1 of Set 13 | bukama
# Processing Record 2 of Set 13 | yar-sale
# Processing Record 3 of Set 13 | porto novo
# Processing Record 4 of Set 13 | sofiysk
# City not found. Skipping...
# Processing Record 5 of Set 13 | sao joaquim
# Processing Record 6 of Set 13 | puerto santander
# Processing Record 7 of Set 13 | lander
# Processing Record 8 of Set 13 | roma
# Processing Record 9 of Set 13 | vuktyl
# Processing Record 10 of Set 13 | lucapa
# Processing Record 11 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 13 | sungaipenuh
# Processing Record 13 of Set 13 | pombia
# Processing Record 14 of Set 13 | keti bandar
# Processing Record 15 of Set 13 | dubti
# Processing Record 16 of Set 13 | san antonio
# Processing Record 17 of Set 13 | ayagoz
# Processing Record 18 of Set 13 | guerrero negro
# Processing Record 19 of Set 13 | thiruvananthapuram
# Processing Record 20 of Set 13 | tignere
# Processing Record 21 of Set 13 | cap-aux-meules
# Processing Record 22 of Set 13 | panama city
# Processing Record 23 of Set 13 | tobermory
# Processing Record 24 of Set 13 | taburi
# City not found. Skipping...
# Processing Record 25 of Set 13 | statesboro
# Processing Record 26 of Set 13 | andevoranto
# City not found. Skipping...
# Processing Record 27 of Set 13 | nurlat
# Processing Record 28 of Set 13 | shelburne
# Processing Record 29 of Set 13 | proddatur
# Processing Record 30 of Set 13 | simplicio mendes
# Processing Record 31 of Set 13 | khani
# Processing Record 32 of Set 13 | sambava
# Processing Record 33 of Set 13 | vestmannaeyjar
# Processing Record 34 of Set 13 | hylkje
# Processing Record 35 of Set 13 | kermanshah
# Processing Record 36 of Set 13 | kukuna
# Processing Record 37 of Set 13 | luanda
# Processing Record 38 of Set 13 | kawalu
# Processing Record 39 of Set 13 | yerbogachen
# Processing Record 40 of Set 13 | basoko
# Processing Record 41 of Set 13 | babushkin
# Processing Record 42 of Set 13 | nsanje
# Processing Record 43 of Set 13 | nuuk
# Processing Record 44 of Set 13 | urozhaynoye
# Processing Record 45 of Set 13 | gdov
# Processing Record 46 of Set 13 | napier
# Processing Record 47 of Set 13 | znamenskoye
# Processing Record 48 of Set 13 | zonguldak
# Processing Record 49 of Set 13 | karaton
# Processing Record 50 of Set 13 | arak
# Processing Record 1 of Set 14 | plouzane
# Processing Record 2 of Set 14 | paucartambo
# City not found. Skipping...
# Processing Record 3 of Set 14 | tiarei
# Processing Record 4 of Set 14 | igrim
# Processing Record 5 of Set 14 | kruisfontein
# Processing Record 6 of Set 14 | balabac
# Processing Record 7 of Set 14 | harbour breton
# Processing Record 8 of Set 14 | axams
# Processing Record 9 of Set 14 | narsaq
# Processing Record 10 of Set 14 | krasnyy yar
# Processing Record 11 of Set 14 | aswan
# Processing Record 12 of Set 14 | qasigiannguit
# Processing Record 13 of Set 14 | shanghai
# Processing Record 14 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 14 | jiroft
# City not found. Skipping...
# Processing Record 16 of Set 14 | ishinomaki
# Processing Record 17 of Set 14 | minot
# Processing Record 18 of Set 14 | kangaatsiaq
# Processing Record 19 of Set 14 | masuda
# Processing Record 20 of Set 14 | muroto
# Processing Record 21 of Set 14 | pandharpur
# Processing Record 22 of Set 14 | simao
# Processing Record 23 of Set 14 | itoman
# Processing Record 24 of Set 14 | valley city
# Processing Record 25 of Set 14 | usinsk
# Processing Record 26 of Set 14 | balsas
# Processing Record 27 of Set 14 | troitskoye
# Processing Record 28 of Set 14 | san diego de los banos
# Processing Record 29 of Set 14 | vaitape
# Processing Record 30 of Set 14 | lake city
# Processing Record 31 of Set 14 | playas
# Processing Record 32 of Set 14 | mustafakemalpasa
# Processing Record 33 of Set 14 | kalaleh
# Processing Record 34 of Set 14 | ayolas
# Processing Record 35 of Set 14 | scottsburgh
# City not found. Skipping...
# Processing Record 36 of Set 14 | roswell
# Processing Record 37 of Set 14 | hastings
# Processing Record 38 of Set 14 | udachnyy
# Processing Record 39 of Set 14 | san felipe
# Processing Record 40 of Set 14 | liancheng
# Processing Record 41 of Set 14 | sitka
# Processing Record 42 of Set 14 | talawdi
# City not found. Skipping...
# Processing Record 43 of Set 14 | alyangula
# Processing Record 44 of Set 14 | hobe sound
# Processing Record 45 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 46 of Set 14 | wang saphung
# Processing Record 47 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 48 of Set 14 | coihaique
# Processing Record 49 of Set 14 | vierzon
# Processing Record 50 of Set 14 | omsukchan
# Processing Record 1 of Set 15 | sampit
# Processing Record 2 of Set 15 | mahibadhoo
# Processing Record 3 of Set 15 | vanimo
# Processing Record 4 of Set 15 | gigmoto
# Processing Record 5 of Set 15 | puerto baquerizo moreno
# Processing Record 6 of Set 15 | ust-nera
# Processing Record 7 of Set 15 | moyale
# Processing Record 8 of Set 15 | rawson
# Processing Record 9 of Set 15 | mokrousovo
# Processing Record 10 of Set 15 | muyezerskiy
# Processing Record 11 of Set 15 | wismar
# Processing Record 12 of Set 15 | xining
# Processing Record 13 of Set 15 | berbera
# Processing Record 14 of Set 15 | aksehir
# Processing Record 15 of Set 15 | russell
# Processing Record 16 of Set 15 | singaparna
# Processing Record 17 of Set 15 | havre-saint-pierre
# Processing Record 18 of Set 15 | poya
# Processing Record 19 of Set 15 | comodoro rivadavia
# Processing Record 20 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 21 of Set 15 | beroroha
# Processing Record 22 of Set 15 | digby
# Processing Record 23 of Set 15 | laukaa
# Processing Record 24 of Set 15 | ugoofaaru
# Processing Record 25 of Set 15 | falealupo
# City not found. Skipping...
# Processing Record 26 of Set 15 | brookhaven
# Processing Record 27 of Set 15 | kerema
# Processing Record 28 of Set 15 | burica
# City not found. Skipping...
# Processing Record 29 of Set 15 | lavumisa
# Processing Record 30 of Set 15 | oranjestad
# Processing Record 31 of Set 15 | ponca city
# Processing Record 32 of Set 15 | gat
# Processing Record 33 of Set 15 | burnie
# Processing Record 34 of Set 15 | ahumada
# City not found. Skipping...
# Processing Record 35 of Set 15 | lafiagi
# Processing Record 36 of Set 15 | itaituba
# Processing Record 37 of Set 15 | kiunga
# Processing Record 38 of Set 15 | starobaltachevo
# Processing Record 39 of Set 15 | colares
# Processing Record 40 of Set 15 | valdosta
# Processing Record 41 of Set 15 | mogok
# Processing Record 42 of Set 15 | tura
# Processing Record 43 of Set 15 | togul
# Processing Record 44 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 45 of Set 15 | tapiramuta
# Processing Record 46 of Set 15 | key west
# Processing Record 47 of Set 15 | monrovia
# Processing Record 48 of Set 15 | pochutla
# Processing Record 49 of Set 15 | khasan
# Processing Record 50 of Set 15 | tonj
# Processing Record 1 of Set 16 | pampa
# Processing Record 2 of Set 16 | marquette
# Processing Record 3 of Set 16 | tumarbong
# Processing Record 4 of Set 16 | wajima
# Processing Record 5 of Set 16 | longyearbyen
# Processing Record 6 of Set 16 | grindavik
# Processing Record 7 of Set 16 | caucaia
# Processing Record 8 of Set 16 | ban nahin
# Processing Record 9 of Set 16 | muncar
# Processing Record 10 of Set 16 | maragogi
# Processing Record 11 of Set 16 | pilani
# Processing Record 12 of Set 16 | pangnirtung
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 707

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Preeceville  51.9500 -102.6677     67.01        45          90
# 1           Albany  42.6001  -73.9662     86.63        48          32
# 2    Leningradskiy  69.3833  178.4167     46.69        74          45
# 3         Denpasar  -8.6500  115.2167     78.46        94          20
# 4  Arraial Do Cabo -22.9661  -42.0278     78.76        69           0
#
#    Wind Speed Country                 Date       Description
# 0        6.80      CA  2022-08-01 18:29:33   overcast clouds
# 1        1.99      US  2022-08-01 18:24:49  scattered clouds
# 2        5.57      RU  2022-08-01 18:29:34  scattered clouds
# 3        9.22      ID  2022-08-01 18:29:34        few clouds
# 4       16.11      BR  2022-08-01 18:29:34         clear sky

# %%
output_data_file = "/Users/vanessac./Desktop/Analysis Projects/World_Weather_Analysis/Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
